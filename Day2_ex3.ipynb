# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import uproot

from coffea import hist
from coffea.nanoaod import NanoEvents
# Defines the file (which is on a remote server). In this case, the file is a specific nanoAOD with more information related to tagger inputs.
fTThad = "root://xrootd-cms.infn.it//store/mc/RunIISummer19UL17NanoAOD/TTToHadronic_TuneCP5_13TeV-powheg-pythia8/NANOAODSIM/106X_mc2017_realistic_v6-v4/100000/01A5544B-5290-3245-9FCA-5E25300AD920.root"
# fTThad="root://xrootd-cms.infn.it//store/mc/RunIISummer19UL17NanoAOD/QCD_Pt_80to120_TuneCP5_13TeV_pythia8/NANOAODSIM/106X_mc2017_realistic_v6-v1/270000/0AB9B1BD-5C2F-6E40-B89D-BF7338B6EA11.root"

# %%
#Deep CSV b-tag
events = NanoEvents.from_file(fTThad)
# Out:
# /afs/cern.ch/work/m/milee/btag/coffea-hats/coffea-hats/lib64/python3.6/site-packages/coffea/util.py:98: Awkward0Warning: In coffea version 0.7 (target date: January 2021), this will be an error.
# (Set awkward1.deprecations_as_errors = True to get a stack trace now.)
# TypeError: <class 'coffea.nanoaod.nanoevents.NanoEvents'> relies exclusively on awkward 0.x and will be removed in upcoming versions of coffea!
#   warnings.warn(message, Awkward0Warning)
# /afs/cern.ch/work/m/milee/btag/coffea-hats/coffea-hats/lib64/python3.6/site-packages/coffea/util.py:98: Awkward0Warning: In coffea version 0.7 (target date: January 2021), this will be an error.
# (Set awkward1.deprecations_as_errors = True to get a stack trace now.)
# TypeError: <class 'coffea.nanoaod.nanoevents.NanoCollection'> relies exclusively on awkward 0.x and will be removed in upcoming versions of coffea!
#   warnings.warn(message, Awkward0Warning)

# %%
L_CSV=0.1355#0.1410
M_CSV=0.4506#0.4590
T_CSV=0.7738#0.7730
L_Flav=0.0532#0.046
M_Flav=0.3040#0.2720
T_Flav=0.7476#0.69

L_CSV_pu=[]
M_CSV_pu=[]
T_CSV_pu=[]
L_Flav_pu=[]
M_Flav_pu=[]
T_Flav_pu=[]
L_CSV_pt=[]
M_CSV_pt=[]
T_CSV_pt=[]
L_Flav_pt=[]
M_Flav_pt=[]
T_Flav_pt=[]
L_CSV_eta=[]
M_CSV_eta=[]
T_CSV_eta=[]
L_Flav_eta=[]
M_Flav_eta=[]
T_Flav_eta=[]
L_CSV_pu_c=[]
M_CSV_pu_c=[]
T_CSV_pu_c=[]
L_Flav_pu_c=[]
M_Flav_pu_c=[]
T_Flav_pu_c=[]
L_CSV_pt_c=[]
M_CSV_pt_c=[]
T_CSV_pt_c=[]
L_Flav_pt_c=[]
M_Flav_pt_c=[]
T_Flav_pt_c=[]
L_CSV_eta_c=[]
M_CSV_eta_c=[]
T_CSV_eta_c=[]
L_Flav_eta_c=[]
M_Flav_eta_c=[]
T_Flav_eta_c=[]
L_CSV_pu_l=[]
M_CSV_pu_l=[]
T_CSV_pu_l=[]
L_Flav_pu_l=[]
M_Flav_pu_l=[]
T_Flav_pu_l=[]
L_CSV_pt_l=[]
M_CSV_pt_l=[]
T_CSV_pt_l=[]
L_Flav_pt_l=[]
M_Flav_pt_l=[]
T_Flav_pt_l=[]
L_CSV_eta_l=[]
M_CSV_eta_l=[]
T_CSV_eta_l=[]
L_Flav_eta_l=[]
M_Flav_eta_l=[]
T_Flav_eta_l=[]

pus=[]
etas=[]
pts=[]


for pu in range(15):
    pus.append(((pu*4)+(pu+1)*4)/2.)
    print(pus[pu])
    L_CSV_pu.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>L_CSV) & (events.Jet.hadronFlavour==5)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==5) & (events.Jet.pt>20.)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepB.flatten())))
    M_CSV_pu.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>M_CSV) & (events.Jet.hadronFlavour==5)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==5) & (events.Jet.pt>20.)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepB.flatten())))
    T_CSV_pu.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>T_CSV) & (events.Jet.hadronFlavour==5)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==5) & (events.Jet.pt>20.)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepB.flatten())))
    L_Flav_pu.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>L_Flav) & (events.Jet.hadronFlavour==5)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==5) & (events.Jet.pt>20.)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepFlavB.flatten())))
    M_Flav_pu.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>M_Flav) & (events.Jet.hadronFlavour==5)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==5) & (events.Jet.pt>20.)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepFlavB.flatten())))
    T_Flav_pu.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>T_Flav) & (events.Jet.hadronFlavour==5)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==5) & (events.Jet.pt>20.)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepFlavB.flatten())))
    L_CSV_pu_c.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>L_CSV) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==4) & (events.Jet.pt>20.)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepB.flatten())))
    M_CSV_pu_c.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>M_CSV) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==4) & (events.Jet.pt>20.)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepB.flatten())))
    T_CSV_pu_c.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>T_CSV) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==4) & (events.Jet.pt>20.)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepB.flatten())))
    L_Flav_pu_c.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>L_Flav) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==4) & (events.Jet.pt>20.)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepFlavB.flatten())))
    M_Flav_pu_c.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>M_Flav) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==4) & (events.Jet.pt>20.)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepFlavB.flatten())))
    T_Flav_pu_c.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>T_Flav) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==4) & (events.Jet.pt>20.)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepFlavB.flatten())))
    L_CSV_pu_l.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>L_CSV) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==0) & (events.Jet.pt>20.)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepB.flatten())))
    M_CSV_pu_l.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>M_CSV) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==0) & (events.Jet.pt>20.)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepB.flatten())))
    T_CSV_pu_l.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>T_CSV) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==0) & (events.Jet.pt>20.)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepB.flatten())))
    L_Flav_pu_l.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>L_Flav) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==0) & (events.Jet.pt>20.)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepFlavB.flatten())))
    M_Flav_pu_l.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>M_Flav) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==0) & (events.Jet.pt>20.)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepFlavB.flatten())))
    T_Flav_pu_l.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>T_Flav) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==0) & (events.Jet.pt>20.)& (events.Pileup.nPU > pu*4) &(events.Pileup.nPU < (pu+1)*4)].btagDeepFlavB.flatten())))
for eta in range(25):
    etas.append((float(-2.4+eta*0.2)+float(-2.4+(eta+1)*0.2))/2.)
    print(etas[eta])
    L_CSV_eta.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>L_CSV) & (events.Jet.hadronFlavour==5)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==5) & (events.Jet.pt>20.)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepB.flatten())))
    M_CSV_eta.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>M_CSV) & (events.Jet.hadronFlavour==5)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==5) & (events.Jet.pt>20.)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepB.flatten())))
    T_CSV_eta.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>T_CSV) & (events.Jet.hadronFlavour==5)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==5) & (events.Jet.pt>20.)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepB.flatten())))
    L_Flav_eta.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>L_Flav) & (events.Jet.hadronFlavour==5)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==5) & (events.Jet.pt>20.)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepFlavB.flatten())))
    M_Flav_eta.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>M_Flav) & (events.Jet.hadronFlavour==5)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==5) & (events.Jet.pt>20.)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepFlavB.flatten())))
    T_Flav_eta.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>T_Flav) & (events.Jet.hadronFlavour==5)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==5) & (events.Jet.pt>20.)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepFlavB.flatten())))
    L_CSV_eta_c.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>L_CSV) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==4) & (events.Jet.pt>20.)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepB.flatten())))
    M_CSV_eta_c.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>M_CSV) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==4) & (events.Jet.pt>20.)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepB.flatten())))
    T_CSV_eta_c.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>T_CSV) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==4) & (events.Jet.pt>20.)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepB.flatten())))
    L_Flav_eta_c.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>L_Flav) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==4) & (events.Jet.pt>20.)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepFlavB.flatten())))
    M_Flav_eta_c.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>M_Flav) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==4) & (events.Jet.pt>20.)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepFlavB.flatten())))
    T_Flav_eta_c.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>T_Flav) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==4) & (events.Jet.pt>20.)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepFlavB.flatten())))
    L_CSV_eta_l.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>L_CSV) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==0) & (events.Jet.pt>20.)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepB.flatten())))
    M_CSV_eta_l.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>M_CSV) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==0) & (events.Jet.pt>20.)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepB.flatten())))
    T_CSV_eta_l.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>T_CSV) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==0) & (events.Jet.pt>20.)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepB.flatten())))
    L_Flav_eta_l.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>L_Flav) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==0) & (events.Jet.pt>20.)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepFlavB.flatten())))
    M_Flav_eta_l.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>M_Flav) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==0) & (events.Jet.pt>20.)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepFlavB.flatten())))
    T_Flav_eta_l.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>T_Flav) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==0) & (events.Jet.pt>20.)& (events.Jet.eta > float(-2.4+eta*0.2)) &(events.Jet.eta < float(-2.4+(eta+1)*0.2))].btagDeepFlavB.flatten())))
for pt in range(20):
    pts.append((float(20+pt*40)+float(20+(pt+1)*40))/2.)    
    L_CSV_pt.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>L_CSV) & (events.Jet.hadronFlavour==5)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==5) & (events.Jet.pt>20.)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepB.flatten())))
    M_CSV_pt.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>M_CSV) & (events.Jet.hadronFlavour==5)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==5) & (events.Jet.pt>20.)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepB.flatten())))
    T_CSV_pt.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>T_CSV) & (events.Jet.hadronFlavour==5)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==5) & (events.Jet.pt>20.)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepB.flatten())))
    L_Flav_pt.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>L_Flav) & (events.Jet.hadronFlavour==5)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==5) & (events.Jet.pt>20.)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepFlavB.flatten())))
    M_Flav_pt.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>M_Flav) & (events.Jet.hadronFlavour==5)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==5) & (events.Jet.pt>20.)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepFlavB.flatten())))
    T_Flav_pt.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>T_Flav) & (events.Jet.hadronFlavour==5)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==5) & (events.Jet.pt>20.)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepFlavB.flatten())))
    L_CSV_pt_c.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>L_CSV) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==4) & (events.Jet.pt>20.)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepB.flatten())))
    M_CSV_pt_c.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>M_CSV) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==4) & (events.Jet.pt>20.)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepB.flatten())))
    T_CSV_pt_c.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>T_CSV) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==4) & (events.Jet.pt>20.)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepB.flatten())))
    L_Flav_pt_c.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>L_Flav) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==4) & (events.Jet.pt>20.)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepFlavB.flatten())))
    M_Flav_pt_c.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>M_Flav) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==4) & (events.Jet.pt>20.)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepFlavB.flatten())))
    T_Flav_pt_c.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>T_Flav) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==4) & (events.Jet.pt>20.)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepFlavB.flatten())))
    L_CSV_pt_l.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>L_CSV) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==0) & (events.Jet.pt>20.)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepB.flatten())))
    M_CSV_pt_l.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>M_CSV) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==0) & (events.Jet.pt>20.)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepB.flatten())))
    T_CSV_pt_l.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>T_CSV) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==0) & (events.Jet.pt>20.)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepB.flatten())))
    L_Flav_pt_l.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>L_Flav) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==0) & (events.Jet.pt>20.)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepFlavB.flatten())))
    M_Flav_pt_l.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>M_Flav) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==0) & (events.Jet.pt>20.)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepFlavB.flatten())))
    T_Flav_pt_l.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>T_Flav) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==0) & (events.Jet.pt>20.)& (events.Jet.pt > float(20+pt*40)) &(events.Jet.pt < float(20+(pt+1)*40))].btagDeepFlavB.flatten())))
# Out:
# 2.0
# 6.0
# 10.0
# 14.0
# 18.0
# 22.0
# 26.0
# 30.0
# 34.0
# 38.0
# 42.0
# 46.0
# 50.0
# 54.0
# 58.0
# -2.3
# -2.0999999999999996
# -1.9
# -1.6999999999999997
# -1.5
# -1.2999999999999998
# -1.0999999999999996
# -0.8999999999999998
# -0.6999999999999998
# -0.4999999999999999
# -0.2999999999999998
# -0.09999999999999964
# 0.10000000000000031
# 0.30000000000000027
# 0.5000000000000002
# 0.7000000000000002
# 0.9000000000000004
# 1.1000000000000003
# 1.3000000000000003
# 1.5000000000000002
# 1.7000000000000002
# 1.9000000000000004
# 2.1000000000000005
# 2.3000000000000007
# 2.5000000000000004

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-746e8bdd3ff2> in <module>
# ----> 1 L_CSV_pu=uproot.TH1D("Loose DeepCSV", "Loose DeepCSV", 20,0,60)
#
# AttributeError: module 'uproot' has no attribute 'TH1D'

# %%
fig, ays = plt.subplots(nrows=3, ncols=3,figsize=(24,24))
ays[0,0].plot(pts,L_Flav_pt,'+g',label="Loose DeepJet",markersize=5)
ays[0,0].plot(pts,M_Flav_pt,'+b',label="Medium DeepJet",markersize=5)
ays[0,0].plot(pts,T_Flav_pt,'+r',label="Tight DeepJet",markersize=5)
ays[0,0].set_xlabel("Jet pT",fontsize=25)
ays[0,0].set_xscale('log')
ays[0,0].set_ylim(0.)
ays[0,0].set_ylabel("B-jet efficiency",fontsize=25)
ays[0,0].legend()
ays[0,1].plot(etas,L_Flav_eta,'+g',label="Loose DeepJet",markersize=5)
ays[0,1].plot(etas,M_Flav_eta,'+b',label="Medium DeepJet",markersize=5)
ays[0,1].plot(etas,T_Flav_eta,'+r',label="Tight DeepJet",markersize=5)
ays[0,1].set_xlabel("Jet eta",fontsize=25)
ays[0,1].set_ylabel("B-jet efficiency",fontsize=25)
ays[0,1].legend()
ays[0,2].plot(pus,L_Flav_pu,'+g',label="Loose DeepJet",markersize=5)
ays[0,2].plot(pus,M_Flav_pu,'+b',label="Medium DeepJet",markersize=5)
ays[0,2].plot(pus,T_Flav_pu,'+r',label="Tight DeepJet",markersize=5)
ays[0,2].set_xlabel("nPU",fontsize=25)
ays[0,2].set_ylabel("B-jet efficiency",fontsize=25)
ays[0,2].legend()
ays[1,0].plot(pts,L_Flav_pt_c,'+g',label="Loose DeepJet",markersize=5)
ays[1,0].plot(pts,M_Flav_pt_c,'+b',label="Medium DeepJet",markersize=5)
ays[1,0].plot(pts,T_Flav_pt_c,'+r',label="Tight DeepJet",markersize=5)
ays[1,0].set_xlabel("Jet pT",fontsize=25)
ays[1,0].set_xscale('log')
ays[1,0].set_ylim(0.)
ays[1,0].set_ylabel("c-jet mistag",fontsize=25)
ays[1,0].legend()
ays[1,1].plot(etas,L_Flav_eta_c,'+g',label="Loose DeepJet",markersize=5)
ays[1,1].plot(etas,M_Flav_eta_c,'+b',label="Medium DeepJet",markersize=5)
ays[1,1].plot(etas,T_Flav_eta_c,'+r',label="Tight DeepJet",markersize=5)
ays[1,1].set_xlabel("Jet eta",fontsize=25)
ays[1,1].set_ylabel("c-jet mistag",fontsize=25)
ays[1,1].legend()
ays[1,2].plot(pus,L_Flav_pu_c,'+g',label="Loose DeepJet",markersize=5)
ays[1,2].plot(pus,M_Flav_pu_c,'+b',label="Medium DeepJet",markersize=5)
ays[1,2].plot(pus,T_Flav_pu_c,'+r',label="Tight DeepJet",markersize=5)
ays[1,2].set_xlabel("nPU",fontsize=25)
ays[1,2].set_ylabel("c-jet mistag",fontsize=25)
ays[1,2].legend()
ays[2,0].plot(pts,L_Flav_pt_l,'+g',label="Loose DeepJet",markersize=5)
ays[2,0].plot(pts,M_Flav_pt_l,'+b',label="Medium DeepJet",markersize=5)
ays[2,0].plot(pts,T_Flav_pt_l,'+r',label="Tight DeepJet",markersize=5)
ays[2,0].set_xlabel("Jet pT",fontsize=25)
ays[2,0].set_xscale('log')
ays[2,0].set_yscale('log')
ays[2,0].set_ylim(0.0001)
ays[2,0].set_ylabel("usd-jet mistag",fontsize=25)
ays[2,0].legend()
ays[2,1].plot(etas,L_Flav_eta_l,'+g',label="Loose DeepJet",markersize=5)
ays[2,1].plot(etas,M_Flav_eta_l,'+b',label="Medium DeepJet",markersize=5)
ays[2,1].plot(etas,T_Flav_eta_l,'+r',label="Tight DeepJet",markersize=5)
ays[2,1].set_xlabel("Jet eta",fontsize=25)
ays[2,1].set_ylabel("usd-jet mistag",fontsize=25)
ays[2,1].set_yscale('log')
ays[2,1].set_ylim(0.0001)
ays[2,1].legend()
ays[2,2].plot(pus,L_Flav_pu_l,'+g',label="Loose DeepJet",markersize=5)
ays[2,2].plot(pus,M_Flav_pu_l,'+b',label="Medium DeepJet",markersize=5)
ays[2,2].plot(pus,T_Flav_pu_l,'+r',label="Tight DeepJet",markersize=5)
ays[2,2].set_xlabel("nPU",fontsize=25)
ays[2,2].set_ylabel("usd-jet mistag",fontsize=25)
ays[2,2].set_yscale('log')
ays[2,2].set_ylim(0.0001)
ays[2,2].legend()
fig.savefig("Eff_flav.png",fontsize=25)
# Out:
# /afs/cern.ch/work/m/milee/btag/coffea-hats/coffea-hats/lib64/python3.6/site-packages/ipykernel_launcher.py:67: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "fontsize" which is no longer supported as of 3.3 and will become an error two minor releases later

# %%
fig, axs = plt.subplots(nrows=3, ncols=3,figsize=(24,24))
axs[0,0].plot(pts,L_CSV_pt,'og',label="Loose CSV",markersize=5)
axs[0,0].plot(pts,M_CSV_pt,'ob',label="Medium CSV",markersize=5)
axs[0,0].plot(pts,T_CSV_pt,'or',label="Tight CSV",markersize=5)
axs[0,0].set_xlabel("Jet pT",fontsize=25)
axs[0,0].set_xscale('log')
axs[0,0].set_ylim(0.)
axs[0,0].set_ylabel("B-jet efficiency",fontsize=25)
axs[0,0].legend()
axs[0,1].plot(etas,L_CSV_eta,'og',label="Loose CSV",markersize=5)
axs[0,1].plot(etas,M_CSV_eta,'ob',label="Medium CSV",markersize=5)
axs[0,1].plot(etas,T_CSV_eta,'or',label="Tight CSV",markersize=5)
axs[0,1].set_xlabel("Jet eta",fontsize=25)
axs[0,1].set_ylabel("B-jet efficiency",fontsize=25)
axs[0,1].legend()
axs[0,2].plot(pus,L_CSV_pu,'og',label="Loose CSV",markersize=5)
axs[0,2].plot(pus,M_CSV_pu,'ob',label="Medium CSV",markersize=5)
axs[0,2].plot(pus,T_CSV_pu,'or',label="Tight CSV",markersize=5)
axs[0,2].set_xlabel("nPU",fontsize=25)
axs[0,2].set_ylabel("B-jet efficiency",fontsize=25)
axs[0,2].legend()
axs[1,0].plot(pts,L_CSV_pt_c,'og',label="Loose CSV",markersize=5)
axs[1,0].plot(pts,M_CSV_pt_c,'ob',label="Medium CSV",markersize=5)
axs[1,0].plot(pts,T_CSV_pt_c,'or',label="Tight CSV",markersize=5)
axs[1,0].set_xlabel("Jet pT",fontsize=25)
axs[1,0].set_xscale('log')
axs[1,0].set_ylim(0.)
axs[1,0].set_ylabel("c-jet mistag",fontsize=25)
axs[1,0].legend()
axs[1,1].plot(etas,L_CSV_eta_c,'og',label="Loose CSV",markersize=5)
axs[1,1].plot(etas,M_CSV_eta_c,'ob',label="Medium CSV",markersize=5)
axs[1,1].plot(etas,T_CSV_eta_c,'or',label="Tight CSV",markersize=5)
axs[1,1].set_xlabel("Jet eta",fontsize=25)
axs[1,1].set_ylabel("c-jet mistag",fontsize=25)
axs[1,1].legend()
axs[1,2].plot(pus,L_CSV_pu_c,'og',label="Loose CSV",markersize=5)
axs[1,2].plot(pus,M_CSV_pu_c,'ob',label="Medium CSV",markersize=5)
axs[1,2].plot(pus,T_CSV_pu_c,'or',label="Tight CSV",markersize=5)
axs[1,2].set_xlabel("nPU",fontsize=25)
axs[1,2].set_ylabel("c-jet mistag",fontsize=25)
axs[1,2].legend()
axs[2,0].plot(pts,L_CSV_pt_l,'og',label="Loose CSV",markersize=5)
axs[2,0].plot(pts,M_CSV_pt_l,'ob',label="Medium CSV",markersize=5)
axs[2,0].plot(pts,T_CSV_pt_l,'or',label="Tight CSV",markersize=5)
axs[2,0].set_xlabel("Jet pT",fontsize=25)
axs[2,0].set_xscale('log')
axs[2,0].set_yscale('log')
axs[2,0].set_ylim(0.0001)
axs[2,0].set_ylabel("usd-jet mistag",fontsize=25)
axs[2,0].legend()
axs[2,1].plot(etas,L_CSV_eta_l,'og',label="Loose CSV",markersize=5)
axs[2,1].plot(etas,M_CSV_eta_l,'ob',label="Medium CSV",markersize=5)
axs[2,1].plot(etas,T_CSV_eta_l,'or',label="Tight CSV",markersize=5)
axs[2,1].set_xlabel("Jet eta",fontsize=25)
axs[2,1].set_ylabel("usd-jet mistag",fontsize=25)
axs[2,1].set_ylim(0.0001)

axs[2,1].set_yscale('log')
axs[2,1].legend()
axs[2,2].plot(pus,L_CSV_pu_l,'og',label="Loose CSV",markersize=5)
axs[2,2].plot(pus,M_CSV_pu_l,'ob',label="Medium CSV",markersize=5)
axs[2,2].plot(pus,T_CSV_pu_l,'or',label="Tight CSV",markersize=5)
axs[2,2].set_xlabel("nPU",fontsize=25)
axs[2,2].set_ylabel("usd-jet mistag",fontsize=25)
axs[2,2].set_ylim(0.0001)

axs[2,2].set_yscale('log')

axs[2,2].legend()
fig.savefig("Eff.png",fontsize=25)
# Out:
# /afs/cern.ch/work/m/milee/btag/coffea-hats/coffea-hats/lib64/python3.6/site-packages/ipykernel_launcher.py:70: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "fontsize" which is no longer supported as of 3.3 and will become an error two minor releases later

# %%
#
