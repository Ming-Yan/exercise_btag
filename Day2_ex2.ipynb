# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import uproot

from coffea import hist
from coffea.nanoaod import NanoEvents
# Defines the file (which is on a remote server). In this case, the file is a specific nanoAOD with more information related to tagger inputs.
fTThad = "root://xrootd-cms.infn.it//store/mc/RunIISummer19UL17NanoAOD/TTToHadronic_TuneCP5_13TeV-powheg-pythia8/NANOAODSIM/106X_mc2017_realistic_v6-v4/100000/01A5544B-5290-3245-9FCA-5E25300AD920.root"
fQCD = "root://xrootd-cms.infn.it//store/mc/RunIISummer19UL17NanoAOD/QCD_Pt_80to120_TuneCP5_13TeV_pythia8/NANOAODSIM/106X_mc2017_realistic_v6-v1/270000/0AB9B1BD-5C2F-6E40-B89D-BF7338B6EA11.root"

# %%
events = NanoEvents.from_file(fTThad)
ev_QCD = NanoEvents.from_file(fQCD)
# Out:
# /afs/cern.ch/work/m/milee/btag/coffea-hats/coffea-hats/lib64/python3.6/site-packages/coffea/util.py:98: Awkward0Warning: In coffea version 0.7 (target date: January 2021), this will be an error.
# (Set awkward1.deprecations_as_errors = True to get a stack trace now.)
# TypeError: <class 'coffea.nanoaod.nanoevents.NanoEvents'> relies exclusively on awkward 0.x and will be removed in upcoming versions of coffea!
#   warnings.warn(message, Awkward0Warning)
# /afs/cern.ch/work/m/milee/btag/coffea-hats/coffea-hats/lib64/python3.6/site-packages/coffea/util.py:98: Awkward0Warning: In coffea version 0.7 (target date: January 2021), this will be an error.
# (Set awkward1.deprecations_as_errors = True to get a stack trace now.)
# TypeError: <class 'coffea.nanoaod.nanoevents.NanoCollection'> relies exclusively on awkward 0.x and will be removed in upcoming versions of coffea!
#   warnings.warn(message, Awkward0Warning)

# %%
cut=[]
csvv2_sig_bvsc=[]
csvv2_bkg_bvsc=[]
deepcsvb_sig_bvsc=[]
deepcsvb_bkg_bvsc=[]
deepcsvc_sig_bvsc=[]
deepcsvc_bkg_bvsc=[]
deepflavb_sig_bvsc=[]
deepflavb_bkg_bvsc=[]
deepflavc_sig_bvsc=[]
deepflavc_bkg_bvsc=[]
csvv2_sig_c=[]
csvv2_bkg_c=[]
deepcsvb_sig_c=[]
deepcsvb_bkg_c=[]
deepcsvc_sig_c=[]
deepcsvc_bkg_c=[]
deepflavb_sig_c=[]
deepflavb_bkg_c=[]
deepflavc_sig_c=[]
deepflavc_bkg_c=[]
csvv2_sig_bvsl=[]
csvv2_bkg_bvsl=[]
deepcsvb_sig_bvsl=[]
deepcsvb_bkg_bvsl=[]
deepcsvc_sig_bvsl=[]
deepcsvc_bkg_bvsl=[]
deepflavb_sig_bvsl=[]
deepflavb_bkg_bvsl=[]
deepflavc_sig_bvsl=[]
deepflavc_bkg_bvsl=[]
csvv2_sig_bvsc_qcd=[]
csvv2_bkg_bvsc_qcd=[]
deepcsvb_sig_bvsc_qcd=[]
deepcsvb_bkg_bvsc_qcd=[]
deepcsvc_sig_bvsc_qcd=[]
deepcsvc_bkg_bvsc_qcd=[]
deepflavb_sig_bvsc_qcd=[]
deepflavb_bkg_bvsc_qcd=[]
deepflavc_sig_bvsc_qcd=[]
deepflavc_bkg_bvsc_qcd=[]
csvv2_sig_c_qcd=[]
csvv2_bkg_c_qcd=[]
deepcsvb_sig_c_qcd=[]
deepcsvb_bkg_c_qcd=[]
deepcsvc_sig_c_qcd=[]
deepcsvc_bkg_c_qcd=[]
deepflavb_sig_c_qcd=[]
deepflavb_bkg_c_qcd=[]
deepflavc_sig_c_qcd=[]
deepflavc_bkg_c_qcd=[]
csvv2_sig_bvsl_qcd=[]
csvv2_bkg_bvsl_qcd=[]
deepcsvb_sig_bvsl_qcd=[]
deepcsvb_bkg_bvsl_qcd=[]
deepcsvc_sig_bvsl_qcd=[]
deepcsvc_bkg_bvsl_qcd=[]
deepflavb_sig_bvsl_qcd=[]
deepflavb_bkg_bvsl_qcd=[]
deepflavc_sig_bvsl_qcd=[]
deepflavc_bkg_bvsl_qcd=[]
err_csvv2_sig_bvsc=[]
err_csvv2_bkg_bvsc=[]
err_deepcsvb_sig_bvsc=[]
err_deepcsvb_bkg_bvsc=[]
err_deepcsvc_sig_bvsc=[]
err_deepcsvc_bkg_bvsc=[]
err_deepflavb_sig_bvsc=[]
err_deepflavb_bkg_bvsc=[]
err_deepflavc_sig_bvsc=[]
err_deepflavc_bkg_bvsc=[]
err_csvv2_sig_c=[]
err_csvv2_bkg_c=[]
err_deepcsvb_sig_c=[]
err_deepcsvb_bkg_c=[]
err_deepcsvc_sig_c=[]
err_deepcsvc_bkg_c=[]
err_deepflavb_sig_c=[]
err_deepflavb_bkg_c=[]
err_deepflavc_sig_c=[]
err_deepflavc_bkg_c=[]
err_csvv2_sig_bvsl=[]
err_csvv2_bkg_bvsl=[]
err_deepcsvb_sig_bvsl=[]
err_deepcsvb_bkg_bvsl=[]
err_deepcsvc_sig_bvsl=[]
err_deepcsvc_bkg_bvsl=[]
err_deepflavb_sig_bvsl=[]
err_deepflavb_bkg_bvsl=[]
err_deepflavc_sig_bvsl=[]
err_deepflavc_bkg_bvsl=[]
err_csvv2_sig_bvsc_qcd=[]
err_csvv2_bkg_bvsc_qcd=[]
err_deepcsvb_sig_bvsc_qcd=[]
err_deepcsvb_bkg_bvsc_qcd=[]
err_deepcsvc_sig_bvsc_qcd=[]
err_deepcsvc_bkg_bvsc_qcd=[]
err_deepflavb_sig_bvsc_qcd=[]
err_deepflavb_bkg_bvsc_qcd=[]
err_deepflavc_sig_bvsc_qcd=[]
err_deepflavc_bkg_bvsc_qcd=[]
err_csvv2_sig_c_qcd=[]
err_csvv2_bkg_c_qcd=[]
err_deepcsvb_sig_c_qcd=[]
err_deepcsvb_bkg_c_qcd=[]
err_deepcsvc_sig_c_qcd=[]
err_deepcsvc_bkg_c_qcd=[]
err_deepflavb_sig_c_qcd=[]
err_deepflavb_bkg_c_qcd=[]
err_deepflavc_sig_c_qcd=[]
err_deepflavc_bkg_c_qcd=[]
err_csvv2_sig_bvsl_qcd=[]
err_csvv2_bkg_bvsl_qcd=[]
err_deepcsvb_sig_bvsl_qcd=[]
err_deepcsvb_bkg_bvsl_qcd=[]
err_deepcsvc_sig_bvsl_qcd=[]
err_deepcsvc_bkg_bvsl_qcd=[]
err_deepflavb_sig_bvsl_qcd=[]
err_deepflavb_bkg_bvsl_qcd=[]
err_deepflavc_sig_bvsl_qcd=[]
err_deepflavc_bkg_bvsl_qcd=[]
for i in range(25):
    cut.append(0.+float(i*1./25))
    print(cut[i])
    csvv2_sig_c.append(float(1.*len(events.Jet[(events.Jet.btagCSVV2>cut[i]) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagCSVV2.flatten()))/float(1.*len(events.Jet[(events.Jet.btagCSVV2>0.) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagCSVV2.flatten())))
    csvv2_bkg_c.append(float(1.*len(events.Jet[(events.Jet.btagCSVV2>cut[i]) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagCSVV2.flatten()))/float(1.*len(events.Jet[(events.Jet.btagCSVV2>0.) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagCSVV2.flatten())))
    deepcsvb_sig_c.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>cut[i]) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepB.flatten())))
    deepcsvb_bkg_c.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>cut[i]) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepB.flatten())))
    deepcsvc_sig_c.append(float(1.*len(events.Jet[(events.Jet.btagDeepC>cut[i]) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepC.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepC>0.) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepC.flatten())))
    deepcsvc_bkg_c.append(float(1.*len(events.Jet[(events.Jet.btagDeepC>cut[i]) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepC.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepC>0.) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepC.flatten())))
    deepflavb_sig_c.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>cut[i]) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepFlavB.flatten())))
    deepflavb_bkg_c.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>cut[i]) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepFlavB.flatten())))
    deepflavc_sig_c.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavC>cut[i]) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepFlavC.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavC>0.) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepFlavC.flatten())))
    deepflavc_bkg_c.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavC>cut[i]) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepFlavC.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavC>0.) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepFlavC.flatten())))
    csvv2_sig_bvsl.append(float(1.*len(events.Jet[(events.Jet.btagCSVV2>cut[i]) & (events.Jet.hadronFlavour==5)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagCSVV2.flatten()))/float(1.*len(events.Jet[(events.Jet.btagCSVV2>0.) & (events.Jet.hadronFlavour==5)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagCSVV2.flatten())))
    csvv2_bkg_bvsl.append(float(1.*len(events.Jet[(events.Jet.btagCSVV2>cut[i]) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagCSVV2.flatten()))/float(1.*len(events.Jet[(events.Jet.btagCSVV2>0.) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagCSVV2.flatten())))
    deepcsvb_sig_bvsl.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>cut[i]) & (events.Jet.hadronFlavour==5)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==5)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepB.flatten())))
    deepcsvb_bkg_bvsl.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>cut[i]) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepB.flatten())))
    deepflavb_sig_bvsl.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>cut[i]) & (events.Jet.hadronFlavour==5)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==5)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepFlavB.flatten())))
    deepflavb_bkg_bvsl.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>cut[i]) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==0)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepFlavB.flatten())))
    csvv2_sig_bvsc.append(float(1.*len(events.Jet[(events.Jet.btagCSVV2>cut[i]) & (events.Jet.hadronFlavour==5)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagCSVV2.flatten()))/float(1.*len(events.Jet[(events.Jet.btagCSVV2>0.) & (events.Jet.hadronFlavour==5)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagCSVV2.flatten())))
    csvv2_bkg_bvsc.append(float(1.*len(events.Jet[(events.Jet.btagCSVV2>cut[i]) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagCSVV2.flatten()))/float(1.*len(events.Jet[(events.Jet.btagCSVV2>0.) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagCSVV2.flatten())))
    deepcsvb_sig_bvsc.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>cut[i]) & (events.Jet.hadronFlavour==5)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==5)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepB.flatten())))
    deepcsvb_bkg_bvsc.append(float(1.*len(events.Jet[(events.Jet.btagDeepB>cut[i]) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepB>0.) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepB.flatten())))
    deepflavb_sig_bvsc.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>cut[i]) & (events.Jet.hadronFlavour==5)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==5)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepFlavB.flatten())))
    deepflavb_bkg_bvsc.append(float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>cut[i]) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepFlavB.flatten()))/float(1.*len(events.Jet[(events.Jet.btagDeepFlavB>0.) & (events.Jet.hadronFlavour==4)& (events.Jet.pt>25)&(abs(events.Jet.eta)<2.4)&(events.Jet.puId>3)].btagDeepFlavB.flatten())))
   
    #     csvv2_sig_c_qcd.append(float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagCSVV2>cut[i]) & (ev_QCD.Jet.hadronFlavour==4)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagCSVV2.flatten()))/float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagCSVV2>0.) & (ev_QCD.Jet.hadronFlavour==4)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagCSVV2.flatten())))
#     csvv2_bkg_c_qcd.append(float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagCSVV2>cut[i]) & (ev_QCD.Jet.hadronFlavour==0)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagCSVV2.flatten()))/float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagCSVV2>0.) & (ev_QCD.Jet.hadronFlavour==0)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagCSVV2.flatten())))
#     deepcsvb_sig_c_qcd.append(float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepB>cut[i]) & (ev_QCD.Jet.hadronFlavour==4)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepB.flatten()))/float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepB>0.) & (ev_QCD.Jet.hadronFlavour==4)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepB.flatten())))
#     deepcsvb_bkg_c_qcd.append(float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepB>cut[i]) & (ev_QCD.Jet.hadronFlavour==0)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepB.flatten()))/float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepB>0.) & (ev_QCD.Jet.hadronFlavour==0)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepB.flatten())))
#     deepcsvc_sig_c_qcd.append(float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepC>cut[i]) & (ev_QCD.Jet.hadronFlavour==4)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepC.flatten()))/float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepC>0.) & (ev_QCD.Jet.hadronFlavour==4)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepC.flatten())))
#     deepcsvc_bkg_c_qcd.append(float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepC>cut[i]) & (ev_QCD.Jet.hadronFlavour==0)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepC.flatten()))/float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepC>0.) & (ev_QCD.Jet.hadronFlavour==0)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepC.flatten())))
#     deepflavb_sig_c_qcd.append(float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepFlavB>cut[i]) & (ev_QCD.Jet.hadronFlavour==4)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepFlavB.flatten()))/float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepFlavB>0.) & (ev_QCD.Jet.hadronFlavour==4)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepFlavB.flatten())))
#     deepflavb_bkg_c_qcd.append(float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepFlavB>cut[i]) & (ev_QCD.Jet.hadronFlavour==0)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepFlavB.flatten()))/float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepFlavB>0.) & (ev_QCD.Jet.hadronFlavour==0)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepFlavB.flatten())))
#     deepflavc_sig_c_qcd.append(float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepFlavC>cut[i]) & (ev_QCD.Jet.hadronFlavour==4)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepFlavC.flatten()))/float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepFlavC>0.) & (ev_QCD.Jet.hadronFlavour==4)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepFlavC.flatten())))
#     deepflavc_bkg_c_qcd.append(float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepFlavC>cut[i]) & (ev_QCD.Jet.hadronFlavour==0)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepFlavC.flatten()))/float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepFlavC>0.) & (ev_QCD.Jet.hadronFlavour==0)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepFlavC.flatten())))
#     csvv2_sig_bvsc_qcd.append(float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagCSVV2>cut[i]) & (ev_QCD.Jet.hadronFlavour==0)&(ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagCSVV2.flatten()))/float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagCSVV2>0.) & (ev_QCD.Jet.hadronFlavour==0)&(ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagCSVV2.flatten())))
#     csvv2_bkg_bvsc_qcd.append(float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagCSVV2>cut[i]) & (ev_QCD.Jet.hadronFlavour==4)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagCSVV2.flatten()))/float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagCSVV2>0.) & (ev_QCD.Jet.hadronFlavour==4)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagCSVV2.flatten())))
#     deepcsvb_sig_bvsc_qcd.append(float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepB>cut[i]) & (ev_QCD.Jet.hadronFlavour==0)&(ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepB.flatten()))/float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepB>0.) & (ev_QCD.Jet.hadronFlavour==0)&(ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepB.flatten())))
#     deepcsvb_bkg_bvsc_qcd.append(float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepB>cut[i]) & (ev_QCD.Jet.hadronFlavour==4)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepB.flatten()))/float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepB>0.) & (ev_QCD.Jet.hadronFlavour==4)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepB.flatten())))
#     deepcsvc_sig_bvsc_qcd.append(float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepC>cut[i]) & (ev_QCD.Jet.hadronFlavour==0)&(ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepC.flatten()))/float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepC>0.) & (ev_QCD.Jet.hadronFlavour==0)&(ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepC.flatten())))
#     deepcsvc_bkg_bvsc_qcd.append(float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepC>cut[i]) & (ev_QCD.Jet.hadronFlavour==4)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepC.flatten()))/float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepC>0.) & (ev_QCD.Jet.hadronFlavour==4)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepC.flatten())))
#     deepflavb_sig_bvsc_qcd.append(float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepFlavB>cut[i]) & (ev_QCD.Jet.hadronFlavour==0)&(ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepFlavB.flatten()))/float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepFlavB>0.) & (ev_QCD.Jet.hadronFlavour==0)&(ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepFlavB.flatten())))
#     deepflavb_bkg_bvsc_qcd.append(float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepFlavB>cut[i]) & (ev_QCD.Jet.hadronFlavour==4)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepFlavB.flatten()))/float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepFlavB>0.) & (ev_QCD.Jet.hadronFlavour==4)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepFlavB.flatten())))
#     deepflavc_sig_bvsc_qcd.append(float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepFlavC>cut[i]) & (ev_QCD.Jet.hadronFlavour==0)&(ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepFlavC.flatten()))/float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepFlavC>0.) & (ev_QCD.Jet.hadronFlavour==0)&(ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepFlavC.flatten())))
#     deepflavc_bkg_bvsc_qcd.append(float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepFlavC>cut[i]) & (ev_QCD.Jet.hadronFlavour==4)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepFlavC.flatten()))/float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepFlavC>0.) & (ev_QCD.Jet.hadronFlavour==4)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepFlavC.flatten())))
#     csvv2_sig_bvsl_qcd.append(float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagCSVV2>cut[i]) & (ev_QCD.Jet.hadronFlavour==0)&(ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagCSVV2.flatten()))/float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagCSVV2>0.) & (ev_QCD.Jet.hadronFlavour==0)&(ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagCSVV2.flatten())))
#     csvv2_bkg_bvsl_qcd.append(float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagCSVV2>cut[i]) & (ev_QCD.Jet.hadronFlavour==0)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagCSVV2.flatten()))/float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagCSVV2>0.) & (ev_QCD.Jet.hadronFlavour==0)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagCSVV2.flatten())))
#     deepcsvb_sig_bvsl_qcd.append(float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepB>cut[i]) & (ev_QCD.Jet.hadronFlavour==0)&(ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepB.flatten()))/float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepB>0.) & (ev_QCD.Jet.hadronFlavour==0)&(ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepB.flatten())))
#     deepcsvb_bkg_bvsl_qcd.append(float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepB>cut[i]) & (ev_QCD.Jet.hadronFlavour==0)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepB.flatten()))/float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepB>0.) & (ev_QCD.Jet.hadronFlavour==0)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepB.flatten())))
#     deepcsvc_sig_bvsl_qcd.append(float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepC>cut[i]) & (ev_QCD.Jet.hadronFlavour==0)&(ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepC.flatten()))/float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepC>0.) & (ev_QCD.Jet.hadronFlavour==0)&(ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepC.flatten())))
#     deepcsvc_bkg_bvsl_qcd.append(float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepC>cut[i]) & (ev_QCD.Jet.hadronFlavour==0)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepC.flatten()))/float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepC>0.) & (ev_QCD.Jet.hadronFlavour==0)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepC.flatten())))
#     deepflavb_sig_bvsl_qcd.append(float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepFlavB>cut[i]) & (ev_QCD.Jet.hadronFlavour==0)&(ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepFlavB.flatten()))/float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepFlavB>0.) & (ev_QCD.Jet.hadronFlavour==0)&(ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepFlavB.flatten())))
#     deepflavb_bkg_bvsl_qcd.append(float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepFlavB>cut[i]) & (ev_QCD.Jet.hadronFlavour==0)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepFlavB.flatten()))/float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepFlavB>0.) & (ev_QCD.Jet.hadronFlavour==0)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepFlavB.flatten())))
#     deepflavc_sig_bvsl_qcd.append(float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepFlavC>cut[i]) & (ev_QCD.Jet.hadronFlavour==0)&(ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepFlavC.flatten()))/float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepFlavC>0.) & (ev_QCD.Jet.hadronFlavour==0)&(ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepFlavC.flatten())))
#     deepflavc_bkg_bvsl_qcd.append(float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepFlavC>cut[i]) & (ev_QCD.Jet.hadronFlavour==0)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepFlavC.flatten()))/float(1.*len(ev_QCD.Jet[(ev_QCD.Jet.btagDeepFlavC>0.) & (ev_QCD.Jet.hadronFlavour==0)& (ev_QCD.Jet.pt>25)&(abs(ev_QCD.Jet.eta)<2.4)&(ev_QCD.Jet.puId>3)].btagDeepFlavC.flatten())))
#    
#    
#     if(deepcsvc_bkg_c[i]<0.11 and deepcsvc_bkg_c[i]>0.09):print("deepcsv C %.2f cut-%.2f" %(deepcsvc_bkg_c[i],cut[i]))
#     if(deepcsvb_bkg_b[i]<0.11 and deepcsvb_bkg_b[i]>0.09):print("deepcsv B %.2f cut-%.2f" %(deepcsvb_bkg_b[i],cut[i]))
#     if(deepflavc_bkg_c[i]<0.11 and deepflavc_bkg_c[i]>0.09):print("deepFlav C %.2f cut-%.2f" %(deepflavc_bkg_c[i],cut[i]))
#     if(deepflavb_bkg_b[i]<0.11 and deepflavb_bkg_b[i]>0.09):print("deepFlav B %.2f cut-%.2f" %(deepflavb_bkg_B[i],cut[i]))        
#     if(deepcsvc_bkg_c[i]<0.02 and deepcsvc_bkg_c[i]>0.005):print("deepcsv C %.2f cut-%.2f" %(deepcsvc_bkg_c[i],cut[i]))
#     if(deepcsvb_bkg_b[i]<0.02 and deepcsvb_bkg_b[i]>0.005):print("deepcsv B %.2f cut-%.2f" %(deepcsvb_bkg_B[i],cut[i]))
#     if(deepflavc_bkg_c[i]<0.02 and deepflavc_bkg_c[i]>0.005):print("deepFlav C %.2f cut-%.2f" %(deepcsvc_bkg_c[i],cut[i]))
#     if(deepflavb_bkg_b[i]<0.02 and deepflavb_bkg_b[i]>0.005):print("deepFlav B %.2f cut-%.2f" %(deepcsvb_bkg_B[i],cut[i]))        
#     if(deepcsvc_bkg_c[i]<0.005 and deepcsvc_bkg_c[i]>0.0001):print("deepcsv C %.2f cut-%.2f" %(deepcsvc_bkg_c[i],cut[i]))
#     if(deepcsvb_bkg_b[i]<0.005 and deepcsvb_bkg_b[i]>0.0001):print("deepcsv B %.2f cut-%.2f" %(deepcsvb_bkg_B[i],cut[i]))
#     if(deepflavc_bkg_c[i]<0.005 and deepflavc_bkg_c[i]>0.0001):print("deepFlav C %.2f cut-%.2f" %(deepcsvc_bkg_c[i],cut[i]))
#     if(deepflavb_bkg_b[i]<0.005 and deepflavb_bkg_b[i]>0.0001):print("deepFlav B %.2f cut-%.2f" %(deepcsvb_bkg_B[i],cut[i]))        
    
    #     print(deepflavc_sig[i],deepflavc_bkg[i])
# Out:
# 0.0
# 0.04
# 0.08
# 0.12
# 0.16
# 0.2
# 0.24
# 0.28
# 0.32
# 0.36
# 0.4
# 0.44
# 0.48
# 0.52
# 0.56
# 0.6
# 0.64
# 0.68
# 0.72
# 0.76
# 0.8
# 0.84
# 0.88
# 0.92
# 0.96

# %%
fig, axs = plt.subplots(nrows=2, ncols=2,figsize=(16,16))
axs[0,0].plot(deepcsvc_sig_c,deepcsvc_bkg_c,color='tab:blue',label="DeepCSV-TTbar")
axs[0,0].plot(deepflavc_sig_c,deepflavc_bkg_c,color='tab:red',label="DeepFlavor-TTbar")
axs[0,0].plot(csvv2_sig_c,csvv2_bkg_c,color='tab:green',label="CSVv2-TTbar")
axs[0,0].set_title("C-Tag")
axs[0,0].set_xlabel("efficiency")
axs[0,0].set_ylabel("Mis-tag")
axs[0,0].legend()
# axs[0,0].set_xscale('log')
axs[0,0].set_yscale('log')
axs[0,0].set_ylim(0.001)
axs[0,1].plot(deepcsvc_sig_c,deepcsvc_bkg_c,color='tab:blue',label="DeepCSV-TTbar")
axs[0,1].plot(deepflavc_sig_c,deepflavc_bkg_c,color='tab:red',label="DeepFlavor-TTbar")
axs[0,1].plot(csvv2_sig_c,csvv2_bkg_c,color='tab:green',label="CSVv2-TTbar")
axs[0,1].set_title("C-Tag")
axs[0,1].set_xlabel("efficiency")
axs[0,1].set_ylabel("Mis-tag")
axs[0,1].legend()
axs[1,0].plot(deepcsvb_sig_bvsc,deepcsvb_bkg_bvsc,color='tab:blue',label="DeepCSV(c)")
axs[1,0].plot(deepcsvb_sig_bvsl,deepcsvb_bkg_bvsl,color='tab:blue',linestyle='dashed',label="DeepCSV(usd)")
axs[1,0].plot(deepflavb_sig_bvsc,deepflavb_bkg_bvsc,color='tab:red',label="DeepJet(c)")
axs[1,0].plot(deepflavb_sig_bvsl,deepflavb_bkg_bvsl,color='tab:red',linestyle='dashed',label="DeepJet(usd)")
axs[1,0].plot(csvv2_sig_bvsc,csvv2_bkg_bvsc,color='tab:green',label="CSVv2(c)")
axs[1,0].plot(csvv2_sig_bvsl,csvv2_bkg_bvsl,color='tab:green',linestyle='dashed',label="CSVv2(usd)")
axs[1,0].set_title("B-tag")
axs[1,0].set_xlabel("efficiency")
axs[1,0].set_ylabel("Mis-tag")
axs[1,0]
axs[1,0].legend()
# axs[1,0].set_xscale('log')
axs[1,0].set_yscale('log')
axs[1,0].set_ylim(0.001)
axs[1,1].plot(deepcsvb_sig_bvsc,deepcsvb_bkg_bvsc,color='tab:blue',label="DeepCSV(c)")
axs[1,1].plot(deepcsvb_sig_bvsl,deepcsvb_bkg_bvsl,color='tab:blue',linestyle='dashed',label="DeepCSV(usd)")
axs[1,1].plot(deepflavb_sig_bvsc,deepflavb_bkg_bvsc,color='tab:red',label="DeepJet(c)")
axs[1,1].plot(deepflavb_sig_bvsl,deepflavb_bkg_bvsl,color='tab:red',linestyle='dashed',label="DeepJet(usd)")
axs[1,1].plot(csvv2_sig_bvsc,csvv2_bkg_bvsc,color='tab:green',label="CSVv2(c)")
axs[1,1].plot(csvv2_sig_bvsl,csvv2_bkg_bvsl,color='tab:green',linestyle='dashed',label="CSVv2(usd)")
axs[1,1].set_title("B-tag")
axs[1,1].set_xlabel("efficiency")
axs[1,1].set_ylabel("Mis-tag")
axs[1,1].legend()

fig.savefig("ROC_TT.png")

# %%
fig, axs = plt.subplots(nrows=2, ncols=2,figsize=(16,16))

axs[0,0].plot(deepcsvc_sig_c_qcd,deepcsvc_bkg_c_qcd,color='tab:cyan',label="DeepCSV-QCD")
axs[0,0].plot(deepflavc_sig_c_qcd,deepflavc_bkg_c_qcd,color='tab:pink',label="DeepFlavor-QCD")
axs[0,0].plot(csvv2_sig_c_qcd,csvv2_bkg_c_qcd,color='lime',label="CSVv2-QCD")
axs[0,0].set_title("C-Tag")
axs[0,0].set_xlabel("efficiency")
axs[0,0].set_ylabel("Mis-tag")
axs[0,0].legend()
axs[0,0].set_xscale('log')
axs[0,0].set_yscale('log')

axs[0,1].plot(deepcsvc_sig_c_qcd,deepcsvc_bkg_c_qcd,color='tab:cyan',label="DeepCSV-QCD")
axs[0,1].plot(deepflavc_sig_c_qcd,deepflavc_bkg_c_qcd,color='tab:pink',label="DeepFlavor-QCD")
axs[0,1].plot(csvv2_sig_c_qcd,csvv2_bkg_c_qcd,color='lime',label="CSVv2-QCD")
axs[0,1].set_title("C-Tag")
axs[0,1].set_xlabel("efficiency")
axs[0,1].set_ylabel("Mis-tag")
axs[0,1].legend()

axs[1,0].plot(deepcsvb_sig_bvsc_qcd,deepcsvb_bkg_bvsc_qcd,color='tab:cyan',label="DeepCSV(c)")
axs[1,0].plot(deepcsvb_sig_bvsl_qcd,deepcsvb_bkg_bvsl_qcd,color='tab:cyan',linestyle='dashed',label="DeepCSV(usd)")
axs[1,0].plot(deepflavb_sig_bvsc_qcd,deepflavb_bkg_bvsc_qcd,color='tab:pink',label="DeepJet(c)")
axs[1,0].plot(deepflavb_sig_bvsl_qcd,deepflavb_bkg_bvsl_qcd,color='tab:pink',linestyle='dashed',label="DeepJet(usd)")
axs[1,0].plot(csvv2_sig_bvsc_qcd,csvv2_bkg_bvsc_qcd,color='lime',label="CSVv2(c)")
axs[1,0].plot(csvv2_sig_bvsl_qcd,csvv2_bkg_bvsl_qcd,color='lime',linestyle='dashed',label="CSVv2(usd)")
axs[1,0].set_title("B-tag")
axs[1,0].set_xlabel("efficiency")
axs[1,0].set_ylabel("Mis-tag")
axs[1,0].legend()
axs[1,0].set_xscale('log')
axs[1,0].set_yscale('log')
axs[1,1].plot(deepcsvb_sig_bvsc_qcd,deepcsvb_bkg_bvsc_qcd,color='tab:cyan',label="DeepCSV(c)")
axs[1,1].plot(deepcsvb_sig_bvsl_qcd,deepcsvb_bkg_bvsl_qcd,color='tab:cyan',linestyle='dashed',label="DeepCSV(usd)")
axs[1,1].plot(deepflavb_sig_bvsc_qcd,deepflavb_bkg_bvsc_qcd,color='tab:pink',label="DeepJet(c)")
axs[1,1].plot(deepflavb_sig_bvsl_qcd,deepflavb_bkg_bvsl_qcd,color='tab:pink',linestyle='dashed',label="DeepJet(usd)")
axs[1,1].plot(csvv2_sig_bvsc_qcd,csvv2_bkg_bvsc_qcd,color='lime',label="CSVv2(c)")
axs[1,1].plot(csvv2_sig_bvsl_qcd,csvv2_bkg_bvsl_qcd,color='lime',linestyle='dashed',label="CSVv2(usd)")
axs[1,1].set_title("B-tag")
axs[1,1].set_xlabel("efficiency")
axs[1,1].set_ylabel("Mis-tag")
axs[1,1].legend()

fig.savefig("ROC_QCD.png")
